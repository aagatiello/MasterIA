# %% [markdown]
# # Tema 6: Random Forest
# ## Cuaderno de ejercicios

# %% [markdown]
# **Ejercicio 1**. Dadas las siguientes predicciones de los árboles pertenecientes a un modelo Random Forest ¿cuál es la predicción final del modelo?
#
# ![Ejercicio1RF.png](attachment:Ejercicio1RF.png)

# %% [markdown]
# **Solución**
#
# En el enunciado no se nos dice qué tipo de problema pretende resolver (clasificación o regresión) pero lo podemos interpretar por los resultados de los RF. Es un problema de clasificación. La decisión de RF para clasificación es la clase más votada. En este caso sería la Clase A.

# %% [markdown]
# **Ejercicio 2.** Dadas las siguientes predicciones de los árboles pertenecientes a un modelo Random Forest para un problema de regresión ¿cuál es la predicción final del modelo?
# ![Ejercicio2RF.png](attachment:Ejercicio2RF.png)

# %% [markdown]
# **Solución**
#
# Es un problema de regresion. La decisión de RF para regresión es la media.

# %%
n_arboles = 5
l_RF = [505, 100, 250, 500, 300]

from statistics import mean

prediction = mean(l_RF)
print(prediction)
# Out:
# 331

# %% [markdown]
# **Ejercicio 3.** En el gráfico se muestra la matriz de confusión y los resultados de las métricas asociadas a ella. La predicción se realiza con un modelo Random Forest. ¿Es un buen modelo? ¿Qué conclusiones podemos sacar de las métricas?
#
# ![Ejercicio3.png](attachment:Ejercicio3.png)

# %% [markdown]
# **Solución.**
#
# Para contestar adecuadamente a esta cuestión hay que mirar todas las métricas. En genral todas parecen buenas, pero en cambio tenemos la especificidad extremadamente baja. Este valor se centra en mirar cuántos de los negativos podemos acertar, en este caso vemos que la clase A la reconoce perfectamente, sin embargo la clase B es dificil para nuestro clasificador. Si nos fijamos, es un problema de datos. El clasificador cuenta con clases desbalanceadas, puede aprender bien a clasificar la clase A porque tiene muchos ejemplos de dicha clase, pero no puede hacer lo mismo con la B, porque cuenta con menos ejemplos que de la clase A.
